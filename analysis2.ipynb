# %%
import csv
with open("all_stocks_and_etfs.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        if "HAL" in row[-1]:
            print(', '.join(row))
# Out:
# 2024-01-25, 37.08, 37.2481, 35.9997, 37.0, 11492073, HAL
# 2024-01-24, 35.68, 36.95, 35.4838, 36.83, 14397273, HAL
# 2024-01-23, 34.48, 35.69, 33.94, 35.3, 15096866, HAL
# 2024-01-22, 33.88, 34.65, 33.775, 34.43, 11147116, HAL
# 2024-01-19, 33.43, 33.98, 33.32, 33.97, 8908991, HAL
# 2024-01-18, 33.21, 33.47, 32.99, 33.31, 6635644, HAL
# 2024-01-17, 32.95, 33.76, 32.84, 33.24, 6985413, HAL
# 2024-01-16, 34.32, 34.45, 33.45, 33.51, 6655997, HAL
# 2024-01-12, 34.81, 34.95, 34.135, 34.48, 6783380, HAL
# 2024-01-11, 34.36, 34.48, 33.96, 34.19, 5973903, HAL
# 2024-01-10, 34.36, 34.51, 33.85, 34.07, 5756597, HAL
# 2024-01-09, 35.09, 35.19, 34.25, 34.51, 7036105, HAL
# 2024-01-08, 35.01, 35.23, 34.165, 35.21, 8938313, HAL
# 2024-01-05, 36.15, 36.305, 35.795, 35.97, 4386218, HAL
# 2024-01-04, 36.85, 36.97, 35.73, 35.78, 7153283, HAL
# 2024-01-03, 36.13, 36.8366, 36.05, 36.57, 6926103, HAL
# 2024-01-02, 36.48, 36.78, 36.0243, 36.12, 5503414, HAL
# ...

# %%
import csv
import matplotlib.pyplot as plt

timestamps = []
opens = []
highs = []
lows = []
closes = []

#Parsing CSV and extracting only HAL data
with open("all_stocks_and_etfs.csv", newline="") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if row['Ticker_Symbol'] == "HAL":
            timestamps.append(row['Date-Time'])
            opens.append(float(row['Open']))
            highs.append(float(row['High']))
            lows.append(float(row['Low']))
            closes.append(float(row['Close']))

plt.figure(figsize=(12, 6))
plt.plot(timestamps, opens, label='Open', color='blue')
plt.plot(timestamps, highs, label='High', color='green')
plt.plot(timestamps, lows, label='Low', color='red')
plt.plot(timestamps, closes, label='Close', color='orange')

plt.title('Stock Prices Over Time (HAL)')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

#Plotting HAL data vs time
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

prices = pd.read_csv("data/all_stocks_and_etfs.csv")

hal_stock_prices_df = prices[prices['Ticker_Symbol'] == 'HAL']

# Extract year from the 'Date' column in production DataFrame
production['Year'] = pd.to_datetime(production['Date'], format='%Y%m').dt.year

# Filter crude oil production data for the time period 1999 to 2023
production = production[(production['Year'] >= 1999) & (production['Year'] <= 2023)]

# Plot stock prices and crude oil production on the same graph
plt.figure(figsize=(12, 6))

plt.plot(hal_stock_prices_df['Date-Time'], hal_stock_prices_df['Open'], label='Open', color='blue')
plt.plot(hal_stock_prices_df['Date-Time'], hal_stock_prices_df['High'], label='High', color='green')
plt.plot(hal_stock_prices_df['Date-Time'], hal_stock_prices_df['Low'], label='Low', color='red')
plt.plot(hal_stock_prices_df['Date-Time'], hal_stock_prices_df['Close'], label='Close', color='orange')
plt.plot(production['Date'], production['Crude Oil Production'], label='Crude Oil Production', color='purple')

plt.title('HAL Stock Prices vs Crude Oil Production (1999-2023)')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 4 prices = pd.read_csv("all_stocks_and_etfs.csv")
#       6 hal_stock_prices_df = prices[prices['Ticker_Symbol'] == 'HAL']
#       8 # Extract year from the 'Date' column in production DataFrame
#
# ...

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
print(sys.executable)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/bin/python3.11
